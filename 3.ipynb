# %% [markdown]
# Идивидуальное задание 1
# Для кожного елементу об'єкту start додати 1. Виправити помилку в стартовому коді

# %%
start = [1,2,3,4]
end = [i+1 for i in range(1, 5)]
print(start)
print(end)
# Out:
# [1, 2, 3, 4]
# [2, 3, 4, 5]

# %% [markdown]
# Індивідуальне завдання №2
# Виправити помилку в стартовому коді

# %%
a = [1, 23, 45, 0, 9]
a.remove(0)
print(a)
# Out:
# [1, 23, 45, 9]

# %% [markdown]
# Індивідуальне завдання №3
# Виправити помилку в стартовому коді

# %%
number = 1
print(number)
# Out:
# 1

# %% [markdown]
# Індивідуальне завдання №4
# Виправити помилку в стартовому коді

# %%
age = input("Сколько вам лет?")
print("У 2020 році мені ", age, " років" )
print(age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-684de0b56535> in <module>
# ----> 1 age = input("Сколько вам лет?")
#       2 print("У 2020 році мені ", age, " років" )
#       3 print(age)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# Індивідуальне завдання №5
# Створити словник із двох списків розмірністю 10, створених раніне. Двома способами

# %%
list('List'*3)
# Out:
# ['L', 'i', 's', 't', 'L', 'i', 's', 't', 'L', 'i', 's', 't']

# %%
l=('L'*4,'i'*4,'st'*4)
print(l)
# Out:
# ('LLLL', 'iiii', 'stststst')

# %% [markdown]
# Індивідуальне завдання №6
# застосувати до 2-х об'єктів множини будь-які 3 операції

# %%
cooked = set()
teacher = set()
users = set()
users.add("Sam")
cooked.add("Misha")
teacher.add("Sasha")
print(cooked)
print(teacher)
print(users)
# Out:
# {'Misha'}
# {'Sasha'}
# {'Sam'}

# %%
users = {"Tom","Bob","Alice","Maria","Sasha","Kat"}
print(len(users))
# Out:
# 6

# %%
users = {"Tom","Bob","Alice"}
users2 = users.copy()
print(users)
print(users2)
# Out:
# {'Tom', 'Alice', 'Bob'}
# {'Tom', 'Alice', 'Bob'}

# %% [markdown]
# Індивідуальне завдання №7
# застосувати до 2-х об'єктів кортеж будь-які 3 операції

# %%
a = tuple('hello world')
print(a)
# Out:
# ('h', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd')

# %%
name_and_age = ('Bob', 42,3)

name_and_age[0]  
name_and_age[1]  
name_and_age[2]
# Out:
# 'Bob'

# %%
name_and_age = ('Bob', 42)

(name, age) = name_and_age
age
name
# Out:
# 'Bob'
